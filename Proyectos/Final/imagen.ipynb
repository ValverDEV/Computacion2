# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from Regresiones import NumMethods
from sympy import symbols
x = symbols('x')

# %%
img = mpimg.imread('road.png')

# %%
len(img)
# Out:
# 100

# %%
plt.imshow(img)

# %%
n = len(img)

Xs = []
Ys = []

matriz = np.zeros((n,n))
for row in range(99,-1,-1):
    for col in range(99,-1,-1):
        if img[row][col][0] > 0:
            matriz[row][col] = 1
            print(row, col)
            Xs.append(100-row)
            Ys.append(100-col)
# Out:
# 82 20
# 81 68
# 81 20
# 80 68
# 80 21
# 79 68
# 79 21
# 78 68
# 78 21
# 77 68
# 77 21
# 76 67
# 76 22
# 75 67
# 75 22
# 74 67
# 74 22
# 73 67
# 73 22
# 72 67
# 72 23
# 71 67
# 71 23
# 70 67
# 70 23
# 69 67
# 69 23
# 68 66
# 68 24
# 67 66
# 67 24
# 66 66
# 66 24
# 65 66
# 65 24
# 64 66
# 64 25
# 63 66
# 63 25
# 62 66
# 62 25
# 61 66
# 61 25
# 60 66
# 60 26
# 59 65
# 59 26
# 58 65
# 58 26
# 57 65
# 57 26
# 56 65
# 56 27
# 55 65
# 55 27
# 54 65
# 54 27
# 53 65
# 53 27
# 52 65
# 52 28
# 51 65
# 51 28
# 50 64
# 50 28
# 49 64
# 49 28
# 48 64
# 48 29
# 47 64
# 47 29
# 46 64
# 46 29
# 45 64
# 45 29
# 44 64
# 44 30
# 43 64
# 43 30
# 42 63
# 42 30
# 41 63
# 41 30
# 40 63
# 40 31
# 39 63
# 39 31
# 38 63
# 38 31
# 37 63
# 37 31
# 36 63
# 36 32
# 35 63
# 35 32
# 34 63
# 34 32
# 33 62
# 33 32
# 32 62
# 32 33
# 31 62
# 31 33
# 30 62
# 30 33
# 29 62
# 29 33
# 28 62
# 28 34
# 27 62
# 27 34
# 26 62
# 26 34
# 25 61
# 25 34
# 24 61
# 24 35
# 23 61
# 23 35
# 22 61
# 22 35
# 21 61

# %%
plt.scatter(Xs,Ys)

# %%
def split_lines(Xs, Ys):
    dist = 20
    Xs1 = []
    Ys1 = []
    
    Xs2 = [Xs[0]]
    Ys2 = [Ys[0]]

    print(Xs2, Ys2)

    for i in range(1, len(Xs)):
        if not(abs(Xs2[-1] - Xs[i]) <= dist and abs(Ys2[-1] - Ys[i]) <= dist):
            Xs1.append(Xs[i])
            Ys1.append(Ys[i])
            break

    for i in range(1, len(Xs)):
        # print(i)
        if abs(Xs2[-1] - Xs[i]) <= dist and abs(Ys2[-1] - Ys[i]) <= dist:
            # print('estamos en el 2o')
            # print(f'anteriores {Xs2[-1]}, {Ys2[-1]}, se añaden {Xs[i], Ys[i]}')
            Xs2.append(Xs[i])
            Ys2.append(Ys[i])
        else:
        # elif abs(Xs1[-1] - Xs[i]) <= 3 and abs(Ys1[-1] - Ys[i]) <= 3:
            # print('estmaos en el 1o')
        #     if Xs1:
            # print(f'anteriores {Xs1[-1]}, {Ys1[-1]}, se añaden {Xs[i], Ys[i]}')
            Xs1.append(Xs[i])
            Ys1.append(Ys[i])

    return Xs1, Ys1, Xs2, Ys2

# %%
X1, Y1, X2, Y2 = split_lines(Xs, Ys)
# Out:
# [18] [80]

# %%
plt.scatter(X1,Y1, color='g')
plt.scatter(X2,Y2, color='r')
plt.show()

# %%
NM = NumMethods(X1, Y1)
lin = NM.linear()
NM.grafica()
poli1 = NM.polinomial(2)
NM.grafica()
# Out:
# 0.11770687351302*x + 29.7248020076264
#  3.54818488554056e-5*x**2 + 0.114260866476519*x + 29.7971425139375

# %%
NM = NumMethods(X2, Y2)
lin = NM.linear()
NM.grafica()
poli2 = NM.polinomial(2)
NM.grafica()
# Out:
# 84.3960867265997 - 0.250396615547329*x
#  1.81395326994502e-5*x**2 - 0.252138010686475*x + 84.4322569548023

# %%
print(lin)
print(lin.diff(x))
# Out:
# 84.3960867265997 - 0.250396615547329*x
# -0.250396615547329

# %%
a = np.arange(0,100, 1)
b1 = [poli1.subs(x, i) for i in a]
b2 = [poli2.subs(x, i) for i in a]

# %%
plt.plot(a, b1)
plt.plot(a, b2)
plt.scatter(Xs, Ys)
plt.show()

# %%
final = (poli2 + poli1)/2
b3 = [final.subs(x, i) for i in a]

# %%
plt.plot(a, b1)
plt.plot(a, b2)
plt.plot(a, b3)
plt.scatter(Xs, Ys)
plt.show()

# %%
final
# Out:
# 2.68106907774279e-5*x**2 - 0.0689385721049781*x + 57.1146997343699

# %%
dfin = final.diff(x)

# %%
b4 = [dfin.subs(x, i) for i in a]

# %%
plt.plot(a, b3)
plt.title('trayectoria')
plt.show()

# %%
plt.plot(a, b4)
plt.title('ajustes')
plt.show()

# %%
b4
# Out:
# [-0.0689385721049781,
#  -0.0688849507234233,
#  -0.0688313293418684,
#  -0.0687777079603136,
#  -0.0687240865787587,
#  -0.0686704651972039,
#  -0.0686168438156490,
#  -0.0685632224340942,
#  -0.0685096010525393,
#  -0.0684559796709844,
#  -0.0684023582894296,
#  -0.0683487369078747,
#  -0.0682951155263199,
#  -0.0682414941447650,
#  -0.0681878727632102,
#  -0.0681342513816553,
#  -0.0680806300001005,
#  -0.0680270086185456,
#  -0.0679733872369907,
#  -0.0679197658554359,
#  -0.0678661444738810,
#  -0.0678125230923262,
#  -0.0677589017107713,
#  -0.0677052803292165,
#  -0.0676516589476616,
#  -0.0675980375661067,
#  -0.0675444161845519,
#  -0.0674907948029970,
#  -0.0674371734214422,
#  -0.0673835520398873,
#  -0.0673299306583325,
#  -0.0672763092767776,
#  -0.0672226878952228,
#  -0.0671690665136679,
#  -0.0671154451321130,
#  -0.0670618237505582,
#  -0.0670082023690033,
#  -0.0669545809874485,
#  -0.0669009596058936,
#  -0.0668473382243388,
#  -0.0667937168427839,
#  -0.0667400954612291,
#  -0.0666864740796742,
#  -0.0666328526981193,
#  -0.0665792313165645,
#  -0.0665256099350096,
#  -0.0664719885534548,
#  -0.0664183671718999,
#  -0.0663647457903451,
#  -0.0663111244087902,
#  -0.0662575030272353,
#  -0.0662038816456805,
#  -0.0661502602641256,
#  -0.0660966388825708,
#  -0.0660430175010159,
#  -0.0659893961194611,
#  -0.0659357747379062,
#  -0.0658821533563514,
#  -0.0658285319747965,
#  -0.0657749105932416,
#  -0.0657212892116868,
#  -0.0656676678301319,
#  -0.0656140464485771,
#  -0.0655604250670222,
#  -0.0655068036854674,
#  -0.0654531823039125,
#  -0.0653995609223577,
#  -0.0653459395408028,
#  -0.0652923181592480,
#  -0.0652386967776931,
#  -0.0651850753961382,
#  -0.0651314540145834,
#  -0.0650778326330285,
#  -0.0650242112514737,
#  -0.0649705898699188,
#  -0.0649169684883640,
#  -0.0648633471068091,
#  -0.0648097257252542,
#  -0.0647561043436994,
#  -0.0647024829621445,
#  -0.0646488615805897,
#  -0.0645952401990348,
#  -0.0645416188174800,
#  -0.0644879974359251,
#  -0.0644343760543702,
#  -0.0643807546728154,
#  -0.0643271332912605,
#  -0.0642735119097057,
#  -0.0642198905281508,
#  -0.0641662691465960,
#  -0.0641126477650411,
#  -0.0640590263834863,
#  -0.0640054050019314,
#  -0.0639517836203766,
#  -0.0638981622388217,
#  -0.0638445408572668,
#  -0.0637909194757120,
#  -0.0637372980941571,
#  -0.0636836767126023,
#  -0.0636300553310474]
